# %%
# Imporing required Packages/Modules
import os
import tensorflow as tf
import datetime
import numpy as np # For array-related manipulations
import pandas as pd # For DataFrame-related operations 
import matplotlib.pyplot as plt # Useful for graph plotting
import seaborn as sns # Another easy graph module
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report # Will be used for model evaluation
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential, load_model # Base class for most Neural Networks
from keras.optimizers import Adam # Model Optimizer for Model fitting
from keras.utils import to_categorical # For converting label to categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, TensorBoard, EarlyStopping
from sklearn.svm import SVC
from keras.layers import Input, Conv2D, MaxPool2D, Dense
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D
from tensorflow.keras.layers import Concatenate, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import time
from keras.utils import to_categorical, plot_model

# %%
data_dir = 'Sugarcane Leaf Image Dataset Split'

Data_Generator = ImageDataGenerator(featurewise_center=False,
                                    rescale=1./255,
                                    #rotation_range=30,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True,
                                    validation_split=0.2)

train_set = Data_Generator.flow_from_directory(directory=data_dir + '/train',
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               batch_size=32,
                                               shuffle=False,
                                               subset='training')


val_set = Data_Generator.flow_from_directory(directory=data_dir + '/validation',
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               batch_size=32,
                                               shuffle=False,
                                               subset='validation')

test_set = ImageDataGenerator(featurewise_center=False,
                              samplewise_center=False,
                              featurewise_std_normalization=False,
                              samplewise_std_normalization=False,
                              rotation_range=0,
                              width_shift_range=0,
                              height_shift_range=0,
                              horizontal_flip=False,
                              vertical_flip=False,
                              rescale=1./255).flow_from_directory(directory=data_dir + '/test',
                                                                  target_size=(224, 224),
                                                                  class_mode='categorical',
                                                                  batch_size=8,
                                                                  shuffle=False)
# Out:
# Found 3884 images belonging to 11 classes.
# Found 104 images belonging to 11 classes.
# Found 1355 images belonging to 11 classes.

# %%
import matplotlib.pyplot as plt

# Extract the images and labels from the batch
images, labels = next(train_set)

# Output the first five images
for i in range(5):
    # Display the current image and label using matplotlib
    plt.imshow(images[i])
    plt.title(f"Image {i + 1} - Label: {labels[i]}")
    plt.show()

# %%
import matplotlib.pyplot as plt

# Extract the images and labels from the batch
images, labels = next(test_set)

# Output the first five images
for i in range(5):
    # Display the current image and label using matplotlib
    plt.imshow(images[i])
    plt.title(f"Image {i + 1} - Label: {labels[i]}")
    plt.show()

# %%
IMAGE_SHAPE = (224, 224, 3)
CLASS_NUM = 11
# create model
def inception(x, filters):
    # 1x1C
    path1 = Conv2D(filters=filters[0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)

    # 1x1->3x3
    path2 = Conv2D(filters=filters[1][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path2 = Conv2D(filters=filters[1][1], kernel_size=(3,3), strides=1, padding='same', activation='relu')(path2)
    
    # 1x1->5x5
    path3 = Conv2D(filters=filters[2][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path3 = Conv2D(filters=filters[2][1], kernel_size=(5,5), strides=1, padding='same', activation='relu')(path3)

    # 3x3->1x1
    path4 = MaxPooling2D(pool_size=(3,3), strides=1, padding='same')(x)
    path4 = Conv2D(filters=filters[3], kernel_size=(1,1), strides=1, padding='same', activation='relu')(path4)

    return Concatenate(axis=-1)([path1,path2,path3,path4])


def auxiliary(x, name=None):
    layer = AveragePooling2D(pool_size=(5,5), strides=3, padding='valid')(x)
    layer = Conv2D(filters=128, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Flatten()(layer)
    layer = Dense(units=256, activation='relu')(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=CLASS_NUM, activation='softmax', name=name)(layer)
    return layer


def googlenet():
    layer_in = Input(shape=IMAGE_SHAPE)
    
    # stage-1
    layer = Conv2D(filters=64, kernel_size=(7,7), strides=2, padding='same', activation='relu')(layer_in)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    layer = BatchNormalization()(layer)

    # stage-2
    layer = Conv2D(filters=64, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Conv2D(filters=192, kernel_size=(3,3), strides=1, padding='same', activation='relu')(layer)
    layer = BatchNormalization()(layer)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)

    # stage-3
    layer = inception(layer, [ 64,  (96,128), (16,32), 32]) #3a
    layer = inception(layer, [128, (128,192), (32,96), 64]) #3b
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-4
    layer = inception(layer, [192,  (96,208),  (16,48),  64]) #4a
    aux1  = auxiliary(layer, name='aux1')
    layer = inception(layer, [160, (112,224),  (24,64),  64]) #4b
    layer = inception(layer, [128, (128,256),  (24,64),  64]) #4c
    layer = inception(layer, [112, (144,288),  (32,64),  64]) #4d
    aux2  = auxiliary(layer, name='aux2')
    layer = inception(layer, [256, (160,320), (32,128), 128]) #4e
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-5
    layer = inception(layer, [256, (160,320), (32,128), 128]) #5a
    layer = inception(layer, [384, (192,384), (48,128), 128]) #5b
    layer = AveragePooling2D(pool_size=(7,7), strides=1, padding='valid')(layer)
    
    # stage-6
    layer = Flatten()(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=256, activation='linear')(layer)
    main = Dense(units=CLASS_NUM, activation='softmax', name='main')(layer)
    
    model = Model(inputs=layer_in, outputs=[main, aux1, aux2])
    
    return model
# train model
model = googlenet()
model.summary()
#model.load_weights(MODEL_NAME)
#tf.keras.utils.plot_model(model, 'GoogLeNet.png')

#optimizer = Adam(lr=2 * 1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
#optimizer = SGD(lr=1 * 1e-1, momentum=0.9, nesterov=True)
#model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 56, 56, 64)  256         ['max_pooling2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 192)  110784      ['conv2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 192)  768        ['conv2d_2[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['batch_normalization_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 96)   18528       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 16)   3088        ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  110720      ['conv2d_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   12832       ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   8224        ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0          ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 192)  221376      ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 96)   76896       ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 64)   16448       ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 480)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 480)  0          ['concatenate_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 96)   46176       ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 16)   7696        ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 480)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 192)  92352       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 208)  179920      ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 48)   19248       ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 64)   30784       ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 160)  82080       ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 224)  226016      ['conv2d_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_26[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 256)  295168      ['conv2d_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_32[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 144)  73872       ['concatenate_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 32)   16416       ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 288)  373536      ['conv2d_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 64)   51264       ['conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 14, 14, 528)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_38[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 160)  84640       ['concatenate_5[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 32)   16928       ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 528)  0          ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 256)  135424      ['concatenate_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 320)  461120      ['conv2d_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 128)  102528      ['conv2d_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 128)  67712       ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 14, 14, 832)  0           ['conv2d_41[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_45[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 160)    133280      ['max_pooling2d_10[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 32)     26656       ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 7, 7, 832)   0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 256)    213248      ['max_pooling2d_10[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 320)    461120      ['conv2d_48[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 128)    102528      ['conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 7, 7, 832)    0           ['conv2d_47[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_51[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 192)    159936      ['concatenate_7[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 48)     39984       ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 384)    319872      ['concatenate_7[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 384)    663936      ['conv2d_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 128)    153728      ['conv2d_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_12[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 7, 7, 1024)   0           ['conv2d_53[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 512)   0           ['concatenate_2[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 4, 4, 528)   0           ['concatenate_5[0][0]']
#  oling2D)
#
#  average_pooling2d_2 (AveragePo  (None, 1, 1, 1024)  0           ['concatenate_8[0][0]']
#  oling2D)
#
#  conv2d_21 (Conv2D)             (None, 4, 4, 128)    65664       ['average_pooling2d[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 4, 4, 128)    67712       ['average_pooling2d_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 1024)         0           ['average_pooling2d_2[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['conv2d_21[0][0]']
#
#  flatten_1 (Flatten)            (None, 2048)         0           ['conv2d_40[0][0]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['flatten_2[0][0]']
#
#  dense (Dense)                  (None, 256)          524544      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 256)          524544      ['flatten_1[0][0]']
#
#  dense_2 (Dense)                (None, 256)          262400      ['dropout_2[0][0]']
#
#  dropout (Dropout)              (None, 256)          0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_1[0][0]']
#
#  main (Dense)                   (None, 11)           2827        ['dense_2[0][0]']
#
#  aux1 (Dense)                   (None, 11)           2827        ['dropout[0][0]']
#
#  aux2 (Dense)                   (None, 11)           2827        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 7,427,921
# Trainable params: 7,427,409
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='googleNet.png', show_shapes=True)

# %%
# optimizer = ['Adam', 'SGD', 'Adam', 'SGD']
# epochs = [20, 30, 20, 30]
# history_all = {}

# for i in range(len(optimizer)):
#     print('Usnig optimizer: ' + optimizer[i] + ', Epoch: ' + str(epochs[i]))
    
#     model.compile(loss='categorical_crossentropy', 
#                   loss_weights={'main': 1.0, 'aux1': 0.3, 'aux2': 0.3},
#                   optimizer=optimizer[i], metrics=['accuracy'])
    
#     train_history = model.fit_generator(
#             train_generator,
#             steps_per_epoch=EPOCH_STEPS,
#             epochs=epochs[i],
#             #callbacks=[checkpoint]
#             shuffle=True
#             )
    
#     # save history    
#     if len(history_all) == 0:
#         history_all = {key: [] for key in train_history.history}
    
#     for key in history_all:
#         history_all[key].extend(train_history.history[key])

# model.save(MODEL_NAME)

# # show train history
# def show_train_history(history, xlabel, ylabel, train):
#     for item in train:
#         plt.plot(history[item])
#     plt.title('Train History')
#     plt.xlabel(xlabel)
#     plt.ylabel(ylabel)
#     plt.legend(train, loc='upper left')
#     plt.show()

# show_train_history(history_all, 'Epoch', 'Accuracy', ('main_acc', 'aux1_acc', 'aux2_acc'))
# show_train_history(history_all, 'Epoch', 'Loss', ('main_loss', 'aux1_loss', 'aux2_loss'))

# %%
# CALLBACKS
# %load_ext tensorboard
# reduce learning rate when val_accuracy has stopped improving
lr_reduce = ReduceLROnPlateau(monitor='val_loss',
                                          factor=0.6,
                                          patience=2,
                                          verbose=1,
                                          mode='max',
                                          min_lr=1e-7)
# stop training when val_accuracy has stopped improving
early_stop = EarlyStopping(monitor='val_loss',
                                       patience=3,
                                       verbose=1,
                                       mode='max')
# callback to save the Keras model and (best) weights obtained on an epoch basis. here, the trained (compiled) model is saved in the current working directory as 'cifar10.h5'
checkpoint = ModelCheckpoint(f'GoogleNet-modelv1-{datetime.datetime.now().__format__("%Y-%m-%d-%H-%M-%S")}.h5',
                                         monitor='val_loss',
                                         verbose=1,
                                         save_weights_only=False,
                                         save_best_only=True,
                                         mode='max',
                                         save_freq='epoch')

#Tensorboard
current_time = datetime.datetime.now().__format__('%Y-%m-%d-%H-%M-%S')
tb_callback = TensorBoard(log_dir=f"./logs/GoogleNetv1-modelv1-{current_time}", histogram_freq=2)

# %%
EPOCH_STEPS = int(4323/BATCH_SIZE)

# Record the start time
start_time = time.time()

# Your existing code for model compilation and training
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

train_history = model.fit(
    train_set,
    batch_size=32,
    validation_data = test_set,
    # steps_per_epoch = EPOCH_STEPS,
    epochs=30,
    verbose =1,
    
    callbacks=[lr_reduce, checkpoint, tb_callback]
)

# Record the end time
end_time = time.time()

# Calculate and print the total training time
total_time = end_time - start_time
print(f"Total training time: {total_time:.2f} seconds")
# Out:
# Epoch 1/30
# 122/122 [==============================] - ETA: 0s - loss: 8.7898 - main_loss: 3.3733 - aux1_loss: 2.7060 - aux2_loss: 2.7105 - main_accuracy: 0.2405 - aux1_accuracy: 0.2266 - aux2_accuracy: 0.2263
# Epoch 1: val_loss improved from -inf to 6.84481, saving model to GoogleNet-modelv1-2023-12-05-22-40-13.h5
# 122/122 [==============================] - 63s 443ms/step - loss: 8.7898 - main_loss: 3.3733 - aux1_loss: 2.7060 - aux2_loss: 2.7105 - main_accuracy: 0.2405 - aux1_accuracy: 0.2266 - aux2_accuracy: 0.2263 - val_loss: 6.8448 - val_main_loss: 2.2245 - val_aux1_loss: 2.3170 - val_aux2_loss: 2.3034 - val_main_accuracy: 0.2546 - val_aux1_accuracy: 0.2546 - val_aux2_accuracy: 0.2546 - lr: 0.0010
# Epoch 2/30
# 122/122 [==============================] - ETA: 0s - loss: 6.7585 - main_loss: 2.2496 - aux1_loss: 2.2390 - aux2_loss: 2.2699 - main_accuracy: 0.2554 - aux1_accuracy: 0.2626 - aux2_accuracy: 0.2485
# Epoch 2: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 354ms/step - loss: 6.7585 - main_loss: 2.2496 - aux1_loss: 2.2390 - aux2_loss: 2.2699 - main_accuracy: 0.2554 - aux1_accuracy: 0.2626 - aux2_accuracy: 0.2485 - val_loss: 6.8210 - val_main_loss: 2.2092 - val_aux1_loss: 2.3438 - val_aux2_loss: 2.2680 - val_main_accuracy: 0.2546 - val_aux1_accuracy: 0.1948 - val_aux2_accuracy: 0.1764 - lr: 0.0010
# Epoch 3/30
# 122/122 [==============================] - ETA: 0s - loss: 6.8251 - main_loss: 2.2796 - aux1_loss: 2.2286 - aux2_loss: 2.3169 - main_accuracy: 0.2472 - aux1_accuracy: 0.2454 - aux2_accuracy: 0.2412
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 3: val_loss did not improve from 6.84481
# 122/122 [==============================] - 45s 367ms/step - loss: 6.8251 - main_loss: 2.2796 - aux1_loss: 2.2286 - aux2_loss: 2.3169 - main_accuracy: 0.2472 - aux1_accuracy: 0.2454 - aux2_accuracy: 0.2412 - val_loss: 6.6312 - val_main_loss: 2.2017 - val_aux1_loss: 2.2214 - val_aux2_loss: 2.2081 - val_main_accuracy: 0.2546 - val_aux1_accuracy: 0.2546 - val_aux2_accuracy: 0.2546 - lr: 0.0010
# Epoch 4/30
# 122/122 [==============================] - ETA: 0s - loss: 6.5448 - main_loss: 2.2283 - aux1_loss: 2.0896 - aux2_loss: 2.2269 - main_accuracy: 0.2554 - aux1_accuracy: 0.2670 - aux2_accuracy: 0.2528
# Epoch 4: val_loss did not improve from 6.84481
# 122/122 [==============================] - 45s 365ms/step - loss: 6.5448 - main_loss: 2.2283 - aux1_loss: 2.0896 - aux2_loss: 2.2269 - main_accuracy: 0.2554 - aux1_accuracy: 0.2670 - aux2_accuracy: 0.2528 - val_loss: 6.6178 - val_main_loss: 2.2031 - val_aux1_loss: 2.2019 - val_aux2_loss: 2.2128 - val_main_accuracy: 0.2546 - val_aux1_accuracy: 0.2546 - val_aux2_accuracy: 0.2546 - lr: 6.0000e-04
# Epoch 5/30
# 122/122 [==============================] - ETA: 0s - loss: 6.5123 - main_loss: 2.2262 - aux1_loss: 2.0728 - aux2_loss: 2.2133 - main_accuracy: 0.2539 - aux1_accuracy: 0.2639 - aux2_accuracy: 0.2366
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
#
# Epoch 5: val_loss did not improve from 6.84481
# 122/122 [==============================] - 45s 372ms/step - loss: 6.5123 - main_loss: 2.2262 - aux1_loss: 2.0728 - aux2_loss: 2.2133 - main_accuracy: 0.2539 - aux1_accuracy: 0.2639 - aux2_accuracy: 0.2366 - val_loss: 6.6350 - val_main_loss: 2.2149 - val_aux1_loss: 2.1883 - val_aux2_loss: 2.2318 - val_main_accuracy: 0.2546 - val_aux1_accuracy: 0.2915 - val_aux2_accuracy: 0.2546 - lr: 6.0000e-04
# Epoch 6/30
# 122/122 [==============================] - ETA: 0s - loss: 6.3061 - main_loss: 2.1725 - aux1_loss: 1.9892 - aux2_loss: 2.1445 - main_accuracy: 0.2673 - aux1_accuracy: 0.3205 - aux2_accuracy: 0.2621
# Epoch 6: val_loss did not improve from 6.84481
# 122/122 [==============================] - 42s 345ms/step - loss: 6.3061 - main_loss: 2.1725 - aux1_loss: 1.9892 - aux2_loss: 2.1445 - main_accuracy: 0.2673 - aux1_accuracy: 0.3205 - aux2_accuracy: 0.2621 - val_loss: 6.5995 - val_main_loss: 2.1927 - val_aux1_loss: 2.2080 - val_aux2_loss: 2.1987 - val_main_accuracy: 0.2554 - val_aux1_accuracy: 0.2583 - val_aux2_accuracy: 0.2546 - lr: 3.6000e-04
# Epoch 7/30
# 122/122 [==============================] - ETA: 0s - loss: 6.0814 - main_loss: 2.0874 - aux1_loss: 1.9361 - aux2_loss: 2.0578 - main_accuracy: 0.2240 - aux1_accuracy: 0.3120 - aux2_accuracy: 0.2464
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
#
# Epoch 7: val_loss did not improve from 6.84481
# 122/122 [==============================] - 44s 360ms/step - loss: 6.0814 - main_loss: 2.0874 - aux1_loss: 1.9361 - aux2_loss: 2.0578 - main_accuracy: 0.2240 - aux1_accuracy: 0.3120 - aux2_accuracy: 0.2464 - val_loss: 5.9082 - val_main_loss: 1.9990 - val_aux1_loss: 1.8977 - val_aux2_loss: 2.0115 - val_main_accuracy: 0.3292 - val_aux1_accuracy: 0.3934 - val_aux2_accuracy: 0.3018 - lr: 3.6000e-04
# Epoch 8/30
# 122/122 [==============================] - ETA: 0s - loss: 5.8714 - main_loss: 2.0154 - aux1_loss: 1.8697 - aux2_loss: 1.9863 - main_accuracy: 0.2340 - aux1_accuracy: 0.3476 - aux2_accuracy: 0.2765
# Epoch 8: val_loss did not improve from 6.84481
# 122/122 [==============================] - 42s 345ms/step - loss: 5.8714 - main_loss: 2.0154 - aux1_loss: 1.8697 - aux2_loss: 1.9863 - main_accuracy: 0.2340 - aux1_accuracy: 0.3476 - aux2_accuracy: 0.2765 - val_loss: 6.3691 - val_main_loss: 2.1146 - val_aux1_loss: 2.1282 - val_aux2_loss: 2.1264 - val_main_accuracy: 0.2517 - val_aux1_accuracy: 0.2716 - val_aux2_accuracy: 0.2568 - lr: 2.1600e-04
# Epoch 9/30
# 122/122 [==============================] - ETA: 0s - loss: 5.7216 - main_loss: 1.9561 - aux1_loss: 1.8176 - aux2_loss: 1.9479 - main_accuracy: 0.3018 - aux1_accuracy: 0.3638 - aux2_accuracy: 0.3167
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
#
# Epoch 9: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 349ms/step - loss: 5.7216 - main_loss: 1.9561 - aux1_loss: 1.8176 - aux2_loss: 1.9479 - main_accuracy: 0.3018 - aux1_accuracy: 0.3638 - aux2_accuracy: 0.3167 - val_loss: 6.5296 - val_main_loss: 2.1589 - val_aux1_loss: 2.1816 - val_aux2_loss: 2.1890 - val_main_accuracy: 0.2546 - val_aux1_accuracy: 0.2458 - val_aux2_accuracy: 0.2546 - lr: 2.1600e-04
# Epoch 10/30
# 122/122 [==============================] - ETA: 0s - loss: 5.4922 - main_loss: 1.8777 - aux1_loss: 1.7253 - aux2_loss: 1.8892 - main_accuracy: 0.3177 - aux1_accuracy: 0.4112 - aux2_accuracy: 0.3399
# Epoch 10: val_loss did not improve from 6.84481
# 122/122 [==============================] - 42s 341ms/step - loss: 5.4922 - main_loss: 1.8777 - aux1_loss: 1.7253 - aux2_loss: 1.8892 - main_accuracy: 0.3177 - aux1_accuracy: 0.4112 - aux2_accuracy: 0.3399 - val_loss: 6.3174 - val_main_loss: 2.1130 - val_aux1_loss: 2.0848 - val_aux2_loss: 2.1195 - val_main_accuracy: 0.2760 - val_aux1_accuracy: 0.2908 - val_aux2_accuracy: 0.2672 - lr: 1.2960e-04
# Epoch 11/30
# 122/122 [==============================] - ETA: 0s - loss: 5.4695 - main_loss: 1.8825 - aux1_loss: 1.7025 - aux2_loss: 1.8845 - main_accuracy: 0.3180 - aux1_accuracy: 0.4189 - aux2_accuracy: 0.3432
# Epoch 11: ReduceLROnPlateau reducing learning rate to 7.775999838486313e-05.
#
# Epoch 11: val_loss did not improve from 6.84481
# 122/122 [==============================] - 44s 356ms/step - loss: 5.4695 - main_loss: 1.8825 - aux1_loss: 1.7025 - aux2_loss: 1.8845 - main_accuracy: 0.3180 - aux1_accuracy: 0.4189 - aux2_accuracy: 0.3432 - val_loss: 6.1755 - val_main_loss: 2.0767 - val_aux1_loss: 2.0239 - val_aux2_loss: 2.0749 - val_main_accuracy: 0.3166 - val_aux1_accuracy: 0.3092 - val_aux2_accuracy: 0.3299 - lr: 1.2960e-04
# Epoch 12/30
# 122/122 [==============================] - ETA: 0s - loss: 5.2654 - main_loss: 1.8225 - aux1_loss: 1.6167 - aux2_loss: 1.8262 - main_accuracy: 0.3543 - aux1_accuracy: 0.4498 - aux2_accuracy: 0.3612
# Epoch 12: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 353ms/step - loss: 5.2654 - main_loss: 1.8225 - aux1_loss: 1.6167 - aux2_loss: 1.8262 - main_accuracy: 0.3543 - aux1_accuracy: 0.4498 - aux2_accuracy: 0.3612 - val_loss: 5.8668 - val_main_loss: 1.9853 - val_aux1_loss: 1.8970 - val_aux2_loss: 1.9845 - val_main_accuracy: 0.3712 - val_aux1_accuracy: 0.3476 - val_aux2_accuracy: 0.3646 - lr: 7.7760e-05
# Epoch 13/30
# 122/122 [==============================] - ETA: 0s - loss: 5.1853 - main_loss: 1.8104 - aux1_loss: 1.5689 - aux2_loss: 1.8060 - main_accuracy: 0.3463 - aux1_accuracy: 0.4719 - aux2_accuracy: 0.3617
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.6655999904032795e-05.
#
# Epoch 13: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 348ms/step - loss: 5.1853 - main_loss: 1.8104 - aux1_loss: 1.5689 - aux2_loss: 1.8060 - main_accuracy: 0.3463 - aux1_accuracy: 0.4719 - aux2_accuracy: 0.3617 - val_loss: 5.8072 - val_main_loss: 1.9844 - val_aux1_loss: 1.8462 - val_aux2_loss: 1.9767 - val_main_accuracy: 0.3491 - val_aux1_accuracy: 0.3712 - val_aux2_accuracy: 0.3631 - lr: 7.7760e-05
# Epoch 14/30
# 122/122 [==============================] - ETA: 0s - loss: 5.0644 - main_loss: 1.7658 - aux1_loss: 1.5296 - aux2_loss: 1.7690 - main_accuracy: 0.3597 - aux1_accuracy: 0.4936 - aux2_accuracy: 0.3883
# Epoch 14: val_loss did not improve from 6.84481
# 122/122 [==============================] - 41s 339ms/step - loss: 5.0644 - main_loss: 1.7658 - aux1_loss: 1.5296 - aux2_loss: 1.7690 - main_accuracy: 0.3597 - aux1_accuracy: 0.4936 - aux2_accuracy: 0.3883 - val_loss: 6.3810 - val_main_loss: 2.1797 - val_aux1_loss: 2.0504 - val_aux2_loss: 2.1509 - val_main_accuracy: 0.3063 - val_aux1_accuracy: 0.2841 - val_aux2_accuracy: 0.3107 - lr: 4.6656e-05
# Epoch 15/30
# 122/122 [==============================] - ETA: 0s - loss: 4.9263 - main_loss: 1.7318 - aux1_loss: 1.4621 - aux2_loss: 1.7324 - main_accuracy: 0.3872 - aux1_accuracy: 0.5224 - aux2_accuracy: 0.3947
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.799360081553459e-05.
#
# Epoch 15: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 348ms/step - loss: 4.9263 - main_loss: 1.7318 - aux1_loss: 1.4621 - aux2_loss: 1.7324 - main_accuracy: 0.3872 - aux1_accuracy: 0.5224 - aux2_accuracy: 0.3947 - val_loss: 6.0752 - val_main_loss: 2.0949 - val_aux1_loss: 1.8990 - val_aux2_loss: 2.0813 - val_main_accuracy: 0.3077 - val_aux1_accuracy: 0.3624 - val_aux2_accuracy: 0.2952 - lr: 4.6656e-05
# Epoch 16/30
# 122/122 [==============================] - ETA: 0s - loss: 4.8252 - main_loss: 1.7041 - aux1_loss: 1.4111 - aux2_loss: 1.7101 - main_accuracy: 0.3677 - aux1_accuracy: 0.5350 - aux2_accuracy: 0.3944
# Epoch 16: val_loss did not improve from 6.84481
# 122/122 [==============================] - 42s 340ms/step - loss: 4.8252 - main_loss: 1.7041 - aux1_loss: 1.4111 - aux2_loss: 1.7101 - main_accuracy: 0.3677 - aux1_accuracy: 0.5350 - aux2_accuracy: 0.3944 - val_loss: 6.1436 - val_main_loss: 2.1478 - val_aux1_loss: 1.9016 - val_aux2_loss: 2.0942 - val_main_accuracy: 0.3203 - val_aux1_accuracy: 0.3513 - val_aux2_accuracy: 0.3203 - lr: 2.7994e-05
# Epoch 17/30
# 122/122 [==============================] - ETA: 0s - loss: 4.7777 - main_loss: 1.6901 - aux1_loss: 1.4004 - aux2_loss: 1.6872 - main_accuracy: 0.3826 - aux1_accuracy: 0.5301 - aux2_accuracy: 0.4022
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.6796160707599483e-05.
#
# Epoch 17: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 352ms/step - loss: 4.7777 - main_loss: 1.6901 - aux1_loss: 1.4004 - aux2_loss: 1.6872 - main_accuracy: 0.3826 - aux1_accuracy: 0.5301 - aux2_accuracy: 0.4022 - val_loss: 6.3427 - val_main_loss: 2.2058 - val_aux1_loss: 1.9762 - val_aux2_loss: 2.1607 - val_main_accuracy: 0.3018 - val_aux1_accuracy: 0.3041 - val_aux2_accuracy: 0.2878 - lr: 2.7994e-05
# Epoch 18/30
# 122/122 [==============================] - ETA: 0s - loss: 4.6612 - main_loss: 1.6571 - aux1_loss: 1.3473 - aux2_loss: 1.6568 - main_accuracy: 0.3875 - aux1_accuracy: 0.5476 - aux2_accuracy: 0.4055
# Epoch 18: val_loss did not improve from 6.84481
# 122/122 [==============================] - 41s 339ms/step - loss: 4.6612 - main_loss: 1.6571 - aux1_loss: 1.3473 - aux2_loss: 1.6568 - main_accuracy: 0.3875 - aux1_accuracy: 0.5476 - aux2_accuracy: 0.4055 - val_loss: 6.0455 - val_main_loss: 2.0987 - val_aux1_loss: 1.8732 - val_aux2_loss: 2.0737 - val_main_accuracy: 0.2790 - val_aux1_accuracy: 0.3306 - val_aux2_accuracy: 0.2768 - lr: 1.6796e-05
# Epoch 19/30
# 122/122 [==============================] - ETA: 0s - loss: 4.6325 - main_loss: 1.6450 - aux1_loss: 1.3454 - aux2_loss: 1.6421 - main_accuracy: 0.4073 - aux1_accuracy: 0.5551 - aux2_accuracy: 0.4215
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.007769642455969e-05.
#
# Epoch 19: val_loss did not improve from 6.84481
# 122/122 [==============================] - 45s 372ms/step - loss: 4.6325 - main_loss: 1.6450 - aux1_loss: 1.3454 - aux2_loss: 1.6421 - main_accuracy: 0.4073 - aux1_accuracy: 0.5551 - aux2_accuracy: 0.4215 - val_loss: 6.0709 - val_main_loss: 2.1041 - val_aux1_loss: 1.8815 - val_aux2_loss: 2.0854 - val_main_accuracy: 0.2827 - val_aux1_accuracy: 0.3262 - val_aux2_accuracy: 0.2745 - lr: 1.6796e-05
# Epoch 20/30
# 122/122 [==============================] - ETA: 0s - loss: 4.5986 - main_loss: 1.6315 - aux1_loss: 1.3294 - aux2_loss: 1.6377 - main_accuracy: 0.4145 - aux1_accuracy: 0.5700 - aux2_accuracy: 0.4225
# Epoch 20: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 355ms/step - loss: 4.5986 - main_loss: 1.6315 - aux1_loss: 1.3294 - aux2_loss: 1.6377 - main_accuracy: 0.4145 - aux1_accuracy: 0.5700 - aux2_accuracy: 0.4225 - val_loss: 6.0749 - val_main_loss: 2.1181 - val_aux1_loss: 1.8749 - val_aux2_loss: 2.0819 - val_main_accuracy: 0.2923 - val_aux1_accuracy: 0.3299 - val_aux2_accuracy: 0.2856 - lr: 1.0078e-05
# Epoch 21/30
# 122/122 [==============================] - ETA: 0s - loss: 4.5728 - main_loss: 1.6248 - aux1_loss: 1.3181 - aux2_loss: 1.6299 - main_accuracy: 0.4119 - aux1_accuracy: 0.5675 - aux2_accuracy: 0.4282
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.046617636457085e-06.
#
# Epoch 21: val_loss did not improve from 6.84481
# 122/122 [==============================] - 45s 365ms/step - loss: 4.5728 - main_loss: 1.6248 - aux1_loss: 1.3181 - aux2_loss: 1.6299 - main_accuracy: 0.4119 - aux1_accuracy: 0.5675 - aux2_accuracy: 0.4282 - val_loss: 5.9555 - val_main_loss: 2.0819 - val_aux1_loss: 1.8382 - val_aux2_loss: 2.0354 - val_main_accuracy: 0.2967 - val_aux1_accuracy: 0.3314 - val_aux2_accuracy: 0.2996 - lr: 1.0078e-05
# Epoch 22/30
# 122/122 [==============================] - ETA: 0s - loss: 4.5460 - main_loss: 1.6134 - aux1_loss: 1.3085 - aux2_loss: 1.6241 - main_accuracy: 0.4117 - aux1_accuracy: 0.5626 - aux2_accuracy: 0.4243
# Epoch 22: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 354ms/step - loss: 4.5460 - main_loss: 1.6134 - aux1_loss: 1.3085 - aux2_loss: 1.6241 - main_accuracy: 0.4117 - aux1_accuracy: 0.5626 - aux2_accuracy: 0.4243 - val_loss: 5.9869 - val_main_loss: 2.0854 - val_aux1_loss: 1.8462 - val_aux2_loss: 2.0553 - val_main_accuracy: 0.2849 - val_aux1_accuracy: 0.3343 - val_aux2_accuracy: 0.2819 - lr: 6.0466e-06
# Epoch 23/30
# 122/122 [==============================] - ETA: 0s - loss: 4.5062 - main_loss: 1.6070 - aux1_loss: 1.2922 - aux2_loss: 1.6069 - main_accuracy: 0.4143 - aux1_accuracy: 0.5729 - aux2_accuracy: 0.4217
# Epoch 23: ReduceLROnPlateau reducing learning rate to 3.6279706364439334e-06.
#
# Epoch 23: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 353ms/step - loss: 4.5062 - main_loss: 1.6070 - aux1_loss: 1.2922 - aux2_loss: 1.6069 - main_accuracy: 0.4143 - aux1_accuracy: 0.5729 - aux2_accuracy: 0.4217 - val_loss: 5.9135 - val_main_loss: 2.0574 - val_aux1_loss: 1.8280 - val_aux2_loss: 2.0281 - val_main_accuracy: 0.2900 - val_aux1_accuracy: 0.3410 - val_aux2_accuracy: 0.2878 - lr: 6.0466e-06
# Epoch 24/30
# 122/122 [==============================] - ETA: 0s - loss: 4.5258 - main_loss: 1.6069 - aux1_loss: 1.3041 - aux2_loss: 1.6147 - main_accuracy: 0.4202 - aux1_accuracy: 0.5623 - aux2_accuracy: 0.4210
# Epoch 24: val_loss did not improve from 6.84481
# 122/122 [==============================] - 44s 359ms/step - loss: 4.5258 - main_loss: 1.6069 - aux1_loss: 1.3041 - aux2_loss: 1.6147 - main_accuracy: 0.4202 - aux1_accuracy: 0.5623 - aux2_accuracy: 0.4210 - val_loss: 5.9735 - val_main_loss: 2.0773 - val_aux1_loss: 1.8498 - val_aux2_loss: 2.0465 - val_main_accuracy: 0.2841 - val_aux1_accuracy: 0.3365 - val_aux2_accuracy: 0.2849 - lr: 3.6280e-06
# Epoch 25/30
# 122/122 [==============================] - ETA: 0s - loss: 4.5092 - main_loss: 1.6014 - aux1_loss: 1.2923 - aux2_loss: 1.6155 - main_accuracy: 0.4150 - aux1_accuracy: 0.5739 - aux2_accuracy: 0.4271
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.1767824364360423e-06.
#
# Epoch 25: val_loss did not improve from 6.84481
# 122/122 [==============================] - 44s 362ms/step - loss: 4.5092 - main_loss: 1.6014 - aux1_loss: 1.2923 - aux2_loss: 1.6155 - main_accuracy: 0.4150 - aux1_accuracy: 0.5739 - aux2_accuracy: 0.4271 - val_loss: 6.0404 - val_main_loss: 2.0988 - val_aux1_loss: 1.8744 - val_aux2_loss: 2.0672 - val_main_accuracy: 0.2804 - val_aux1_accuracy: 0.3314 - val_aux2_accuracy: 0.2775 - lr: 3.6280e-06
# Epoch 26/30
# 122/122 [==============================] - ETA: 0s - loss: 4.4751 - main_loss: 1.5920 - aux1_loss: 1.2779 - aux2_loss: 1.6052 - main_accuracy: 0.4184 - aux1_accuracy: 0.5744 - aux2_accuracy: 0.4313
# Epoch 26: val_loss did not improve from 6.84481
# 122/122 [==============================] - 43s 354ms/step - loss: 4.4751 - main_loss: 1.5920 - aux1_loss: 1.2779 - aux2_loss: 1.6052 - main_accuracy: 0.4184 - aux1_accuracy: 0.5744 - aux2_accuracy: 0.4313 - val_loss: 6.0269 - val_main_loss: 2.1013 - val_aux1_loss: 1.8613 - val_aux2_loss: 2.0644 - val_main_accuracy: 0.2782 - val_aux1_accuracy: 0.3277 - val_aux2_accuracy: 0.2775 - lr: 2.1768e-06
# Epoch 27/30
# 122/122 [==============================] - ETA: 0s - loss: 4.4819 - main_loss: 1.5923 - aux1_loss: 1.2838 - aux2_loss: 1.6058 - main_accuracy: 0.4199 - aux1_accuracy: 0.5731 - aux2_accuracy: 0.4246
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.3060694072919432e-06.
#
# Epoch 27: val_loss did not improve from 6.84481
# 122/122 [==============================] - 44s 360ms/step - loss: 4.4819 - main_loss: 1.5923 - aux1_loss: 1.2838 - aux2_loss: 1.6058 - main_accuracy: 0.4199 - aux1_accuracy: 0.5731 - aux2_accuracy: 0.4246 - val_loss: 5.9958 - val_main_loss: 2.0897 - val_aux1_loss: 1.8518 - val_aux2_loss: 2.0543 - val_main_accuracy: 0.2812 - val_aux1_accuracy: 0.3299 - val_aux2_accuracy: 0.2812 - lr: 2.1768e-06
# Epoch 28/30
# 122/122 [==============================] - ETA: 0s - loss: 4.4837 - main_loss: 1.5898 - aux1_loss: 1.2850 - aux2_loss: 1.6089 - main_accuracy: 0.4179 - aux1_accuracy: 0.5705 - aux2_accuracy: 0.4297
# Epoch 28: val_loss did not improve from 6.84481
# 122/122 [==============================] - 44s 361ms/step - loss: 4.4837 - main_loss: 1.5898 - aux1_loss: 1.2850 - aux2_loss: 1.6089 - main_accuracy: 0.4179 - aux1_accuracy: 0.5705 - aux2_accuracy: 0.4297 - val_loss: 6.0109 - val_main_loss: 2.0932 - val_aux1_loss: 1.8594 - val_aux2_loss: 2.0583 - val_main_accuracy: 0.2804 - val_aux1_accuracy: 0.3292 - val_aux2_accuracy: 0.2797 - lr: 1.3061e-06
# Epoch 29/30
# 122/122 [==============================] - ETA: 0s - loss: 4.4817 - main_loss: 1.5938 - aux1_loss: 1.2898 - aux2_loss: 1.5981 - main_accuracy: 0.4163 - aux1_accuracy: 0.5675 - aux2_accuracy: 0.4333
# Epoch 29: ReduceLROnPlateau reducing learning rate to 7.836416443751659e-07.
#
# Epoch 29: val_loss did not improve from 6.84481
# 122/122 [==============================] - 44s 363ms/step - loss: 4.4817 - main_loss: 1.5938 - aux1_loss: 1.2898 - aux2_loss: 1.5981 - main_accuracy: 0.4163 - aux1_accuracy: 0.5675 - aux2_accuracy: 0.4333 - val_loss: 6.0021 - val_main_loss: 2.0921 - val_aux1_loss: 1.8530 - val_aux2_loss: 2.0570 - val_main_accuracy: 0.2812 - val_aux1_accuracy: 0.3292 - val_aux2_accuracy: 0.2790 - lr: 1.3061e-06
# Epoch 30/30
# 122/122 [==============================] - ETA: 0s - loss: 4.4665 - main_loss: 1.5875 - aux1_loss: 1.2767 - aux2_loss: 1.6023 - main_accuracy: 0.4161 - aux1_accuracy: 0.5713 - aux2_accuracy: 0.4289
# Epoch 30: val_loss did not improve from 6.84481
# 122/122 [==============================] - 42s 345ms/step - loss: 4.4665 - main_loss: 1.5875 - aux1_loss: 1.2767 - aux2_loss: 1.6023 - main_accuracy: 0.4161 - aux1_accuracy: 0.5713 - aux2_accuracy: 0.4289 - val_loss: 6.0080 - val_main_loss: 2.0901 - val_aux1_loss: 1.8610 - val_aux2_loss: 2.0570 - val_main_accuracy: 0.2804 - val_aux1_accuracy: 0.3358 - val_aux2_accuracy: 0.2782 - lr: 7.8364e-07
# Total training time: 1319.90 seconds

# %%
import matplotlib.pyplot as plt

# Assuming you have the training history stored in the variable 'train_history'

# Plot the training loss
plt.plot(train_history.history['loss'], label='Training Loss')

# Plot the validation loss
plt.plot(train_history.history['val_loss'], label='Validation Loss')

plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have the training history stored in the variable 'train_history'

# Plot the training accuracy
plt.plot(train_history.history['main_accuracy'], label='Training Accuracy')

# Plot the validation accuracy
plt.plot(train_history.history['val_main_accuracy'], label='Validation Accuracy')

plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have the true labels and predicted labels for the test set
true_labels = test_set.classes

# Ensure that model.predict returns a NumPy array
predicted_probs = model.predict(test_set)
if isinstance(predicted_probs, list):
    # Concatenate the predictions from multiple branches (assuming main branch is the first)
    predicted_probs = np.concatenate(predicted_probs, axis=1)

# Convert predicted probabilities to class indices
predicted_labels = predicted_probs.argmax(axis=1)

# Compute confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 170/170 [==============================] - 6s 33ms/step

# %%
import matplotlib.pyplot as plt

# Display the first image in the batch
plt.imshow(images[0])
plt.show()

# %% [markdown]
# # Constraints

# %%
# Extract a batch of images from your dataset
images, _ = next(test_set)

# Measure inference time for making predictions
start_time = time.time()

# Assuming your model is named 'model' and you want predictions for the batch of images
predictions = model.predict(images)

end_time = time.time()

# Calculate and print the inference time
inference_time = end_time - start_time
print(f"Inference Time: {inference_time:.4f} seconds")
# Out:
# 1/1 [==============================] - 0s 394ms/step
# Inference Time: 0.4328 seconds

# %%
def get_model_size(model):
    # Save the model to a temporary file
    model.save('temp_model.h5')

    # Get the size of the saved model file
    model_size = os.path.getsize('temp_model.h5')

    # Remove the temporary file
    os.remove('temp_model.h5')

    return model_size

# Load your model
model = tf.keras.models.load_model(r'D:\New_Fourth_Year\projectDesignGit\GoogleNet-modelv1-2023-12-05-22-40-13.h5')

# Get the size of the model
model_size_bytes = get_model_size(model)

# Convert bytes to megabytes for better readability
model_size_megabytes = model_size_bytes / (1024 * 1024)

print(f"Model Size: {model_size_megabytes:.2f} MB")
# Out:
# Model Size: 85.57 MB

# %%
model = tf.keras.models.load_model(r'D:\New_Fourth_Year\projectDesignGit\GoogleNet-modelv1-2023-12-05-22-40-13.h5')
# Assuming you have a test set generator
test_set = test_set  # Define or load your test set generator

# Use model.evaluate to get accuracy and other metrics
results = model.evaluate(test_set, verbose=1)  # Set verbose=1 for more information

# 'results' is a list containing the evaluation metrics
accuracy = results[1]  # Index 1 corresponds to the accuracy

# Compute misclassification rate
misclassification_rate = 1 - accuracy

print(f'Misclassification Rate: {misclassification_rate * 100:.2f}%')
# Out:
# 170/170 [==============================] - 6s 30ms/step - loss: 6.8448 - main_loss: 2.2245 - aux1_loss: 2.3170 - aux2_loss: 2.3034 - main_accuracy: 0.2546 - aux1_accuracy: 0.2546 - aux2_accuracy: 0.2546
# Misclassification Rate: -122.45%

# %%
# 'results' is a list containing the evaluation metrics
main_accuracy = results[4]  # Index 4 corresponds to the accuracy of the main branch

print(f'Main Branch Accuracy: {main_accuracy:.2%}')
# Out:
# Main Branch Accuracy: 25.46%

# %%
from sklearn.metrics import accuracy_score

# Assuming you have the true labels and predicted labels for the test set
true_labels = test_set.classes

# Ensure that model.predict returns a NumPy array
predicted_probs = model.predict(test_set)
if isinstance(predicted_probs, list):
    # Concatenate the predictions from multiple branches (assuming main branch is the first)
    predicted_probs = np.concatenate(predicted_probs, axis=1)

# Convert predicted probabilities to class labels
predicted_labels = predicted_probs.argmax(axis=1)

# Compute accuracy using sklearn's accuracy_score
accuracy = accuracy_score(true_labels, predicted_labels)

# Compute misclassification rate
misclassification_rate = 1 - accuracy

print(f'Misclassification Rate: {misclassification_rate:.2%}')
# Out:
# 170/170 [==============================] - 6s 33ms/step
# Misclassification Rate: 96.31%

# %%
def get_flops(model_h5_path):
    session = tf.compat.v1.Session()
    graph = tf.compat.v1.get_default_graph()


    with graph.as_default():
        with session.as_default():
            model = tf.keras.models.load_model(model_h5_path)

            run_meta = tf.compat.v1.RunMetadata()
            opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()

            # We use the Keras session graph in the call to the profiler.
            flops = tf.compat.v1.profiler.profile(graph=graph,
                                                  run_meta=run_meta, cmd='op', options=opts)

            return flops.total_float_ops

# %%
model_h5_path = r'D:\New_Fourth_Year\projectDesignGit\GoogleNet-modelv1-2023-12-05-22-40-13.h5'
# Get and print the FLOPs
flops = get_flops(model_h5_path)
print(f"Number of FLOPs: {flops}")
# Out:
# WARNING:tensorflow:From C:\Users\Jerico\AppData\Roaming\Python\Python38\site-packages\keras\layers\normalization\batch_normalization.py:514: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Jerico\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\profiler\internal\flops_registry.py:138: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Number of FLOPs: 7419667
